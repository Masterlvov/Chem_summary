# %%
# 碳材料
## 石墨

### 石墨本身特性


### 石墨生产过程和工艺
焦原料 $\rightarrow$ 粉碎整形 $\rightarrow$ 造粒 $\rightarrow$ 石墨化 $\rightarrow$ 包覆碳化 $\rightarrow$ 成品筛选

焦原料 $\rightarrow$ 粉碎整形 $\rightarrow$ 石墨化 $\rightarrow$ 造粒  $\rightarrow$  包覆碳化 $\rightarrow$ 成品筛选 

焦原料  $\rightarrow$ 粉碎整形 $\rightarrow$ 石墨化  $\rightarrow$ 成品筛选

### 石墨焦原料


### 骨料粒径

### 二次颗粒制备
- 造粒考虑粘接剂种类及用量。 造粒和石墨化的先后顺序（影响残碳的比例）。 造粒完

### 包覆
- 包覆考虑碳源成分及用量。（实现方式固相、液相、气相包覆（）碳化温度（1000-1250 deg） 软化点温度（180-250 deg） ）
- 包覆对啥产生影响
  - 锂离子脱溶剂化脱嵌位点多，
  - 同样和电解液接触多，更容易电解液反应，因此高温下寿命差，产气多。
  - 包覆完导电性变好
  - 包覆完软碳晶界多，更硬，所以更难压，相同压力下，压实更低。
- 包覆


## 硬碳HC
### 硬碳特性

# %% [markdown]
# 370 面密度        6 min   已达成     但温度较高70-80℃，对寿命影响较大
# 460 面密度        10min
#
# 随着倍率增大，DCIR呈现减小趋势，当DCIR变化趋势出现拐点则说明功率出现拐点。
# 相比常温，高温充电容量多，但放电容量少，导致能量效率降低。（倍率都多大？）
# 相比常温，低温下充电容量少，放电容量也少，能量效率变化不显著。（倍率都多大？）

# %% [markdown]
# | Coulombic Efficiency | 1000圈后的容量保持率 |
# | --------------------- | -------------------- |
# | 0.9999             | 0.904832894          |
# | 0.9998             | 0.818714376          |
# | 0.9997              | 0.740784878          |
# | 0.9996              | 0.670266408          |

# %% [markdown]
# 快充下锂离子由于扩散层的快速增长，导致底层锂离子快速反应完之后锂离子无法扩散到电极深处，导致锂离子扩散至可到达区域（表层石墨）的活性物质嵌锂饱和后（嵌锂过电势高于析锂过电势），石墨表面发生析锂；而底层石墨双电层快速充电，电势降低。使得负极表面SOC高，电位低，在石墨表面析锂。
#
# 那么如何让锂离子能够更好的扩散进电极深处，根据菲克扩散定律，我们可以知道，扩散通量取决于浓度差以及时间（或者扩散距离（特征时间$\tau = L^2/D$））。那么要么相同时间内浓度差足够大，要么扩散距离很短。
#
# 扩散距离其实由于电极设计参数比如面密度、压实使得很难改变（但可以设计相同压实下的不同孔隙结构实现），但一开始的浓度差是可以通过劣化表层并优化底层的反应能力来实现的。但是表层的能力又不能太差，防止表层能力太差而析锂。
#
# 文献里以及早期实验都明确了电极设计需要上大下小孔隙结构，这个是可以认为是改变锂离子有效扩散距离，
